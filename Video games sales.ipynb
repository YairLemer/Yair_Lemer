# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Reviewer's comment</b>
#
# Hello, my name is Sveta Nosova and I am going to review this project.
#
# Before we start, I want to pay your attention to the color marking:
#
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment</b>
#
# Great solutions and ideas that can and should be used in the future are in green comments.
# </div>
#
#
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment</b>
#
# Yellow color indicates what should be optimized. This is not necessary, but it will be great if you make changes to this project.
# </div>
#
#
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment</b>
#
# Issues that need to be corrected to get right results are indicated in red comments. Note that the project cannot be accepted until these issues are resolved.
# </div>
#
# <hr>
#
# **Please, use some color other than those listed to highlight answers to my comments.**
# I would also ask you **not to change, move or delete my comments** so that it would be easier for me to navigate during the next review.
#
# In addition, my comments are defined as headings.
# They can mess up the content; however, they are convenient, since you can immediately go to them. I will remove the headings from my comments in the next review.
#
#
#
# <hr>
#
# <font color='dodgerblue'>**A few words about the project:**</font> you did a good job, everything is clear and neat, there are  analysis and intermediate conclusions. I still have some questions that I've written in my comments. I've also left there some recommendations for improving the project.
#
#
# I will wait for the project for a second review :)
#
#
#
# </div>

# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Reviewer's comment 2</b>
#
#
# Thank you for sending the corrected version of the project. I've left a few comments titled as **Reviewer's comment 2**. Unfortunately, not all issues were fixed. Check out my comments and make sure that all cells work fine.
#
#
#
#
# </div>
# <hr>
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Reviewer's comment 3</b>
#
#
# In new comments with digit 3 I've left some recommendations and tried to answer your question. Don't worry, there is just a typo that caused such result. I explained how to fix that.
#
#
#
#
# </div>
# <hr>
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Reviewer's comment 4</b>
#
#
# You almost finished the project! I am happy to see the results. There are still some issues that need your attention, but it should not take much time.
#
#
# I will also twy to review the next version as fast as I can.
#
#
#
# </div>
# <hr>
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Reviewer's comment 5</b>
#
#
# I've left a brief explanation why the cell did not work. Also, remember that we have tutors and they may answer much more quickly than I do in a review. So, I hope my comments will help 😉
#
# </div>
# <hr>
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Reviewer's comment 6</b>
#
#
# There's a couple of questions this time.
# </div>
# <hr>
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Reviewer's comment 7</b>
#
#
# Last question. Let's fix that rating issue. </div>
# <hr>
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Reviewer's comment 8</b>
#
#
# Everything is great now, thank you for your patience and diligence. I did not leave any new comments this time. Please do not change or move reviewer's code in the next projects.
#
# Good luck! </div>

# %% [raw]
# Step 2. Prepare the data
# Replace the column names (make them lowercase).
# Convert the data to the required types.
# Describe the columns where the data types have been changed and why.
# If necessary, decide how to deal with missing values:
# Explain why you filled in the missing values as you did or why you decided to leave them blank.
# Why do you think the values are missing? Give possible reasons.
# Pay attention to the abbreviation TBD (to be determined). Specify how you intend to handle such cases.
# Calculate the total sales (the sum of sales in all regions) for each game and put these values in a separate column.
#
# Step 3. Analyze the data
# Look at how many games were released in different years. Is the data for every period significant?
# Look at how sales varied from platform to platform. Choose the platforms with the greatest total sales and build a distribution based on data for each year. Find platforms that used to be popular but now have zero sales. How long does it generally take for new platforms to appear and old ones to fade?
# Determine what period you should take data for. To do so, look at your answers to the previous questions. The data should allow you to build a prognosis for 2017.
# Work only with the data that you've decided is relevant. Disregard the data for previous years.
# Which platforms are leading in sales? Which ones are growing or shrinking? Select several potentially profitable platforms.
# Build a box plot for the global sales of all games, broken down by platform. Are the differences in sales significant? What about average sales on various platforms? Describe your findings.
# Take a look at how user and professional reviews affect sales for one popular platform (you choose). Build a scatter plot and calculate the correlation between reviews and sales. Draw conclusions.
# Keeping your conclusions in mind, compare the sales of the same games on other platforms.
# Take a look at the general distribution of games by genre. What can we say about the most profitable genres? Can you generalize about genres with high and low sales?
#
# Step 4. Create a user profile for each region
# For each region (NA, EU, JP), determine:
# The top five platforms. Describe variations in their market shares from region to region.
# The top five genres. Explain the difference.
# Do ESRB ratings affect sales in individual regions?
#
# Step 5. Test the following hypotheses:
# —Average user ratings of the Xbox One and PC platforms are the same.
# —Average user ratings for the Action and Sports genres are different.
# Set the alpha threshold value yourself.
# Explain:
# —How you formulated the null and alternative hypotheses
# —What significance level you chose to test the hypotheses, and why
#
#
# Step 6. Write a general conclusion
# Format: Complete the task in the Jupyter Notebook. Insert the programming code in the code cells and text explanations in the markdown cells. Apply formatting and add headings.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment</b>
#
# There's an introduction, which is good. It is important to write an introductory part, because it gives an idea about the content of the project.
# </div>
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>  Reviewer's comment </b>
#
#
# You can use Markdown cell, by the way.
# </div>

# %% [markdown]
# # Step 1

# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
import random
import numpy
import seaborn as sns
from scipy import stats as st

# %%
try:
    df = pd.read_csv('games.csv')
except:
    df = pd.read_csv('/datasets/games.csv') 

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>  Reviewer's comment </b>
#
# It's very good that you use `try-except`. Although it is usually used for catching some specific exceptions, it can be used here as well. Another good practice is to add `else` and `finally`. Thus, `try` block allows us to handle some error. The `except` block catches the exceptions. `else` does something if there's no error. `finally` is to be executed in any case, whether there is an exception or not (it is useful when you definitely need to do something, for example, to close a file).
#
#
# Look at this code snippet:
# </div>
#
# ```python
#
# try:
#     # Try to do smth here.
# except Exception as e:
#     # Handle an instance of SomeException.
#     # So we deal with the expected error.
# else:
#     # Do smth if there is no exception.
# finally:
#     # Do something no matter what.
#
# ```

# %% [markdown]
# # Step 2

# %%
df.describe(include="all")
# Out:
#                                Name Platform  Year_of_Release   Genre  \
# count                         16713    16715     16446.000000   16713
# unique                        11559       31              NaN      12
# top     Need for Speed: Most Wanted      PS2              NaN  Action
# freq                             12     2161              NaN    3369
# mean                            NaN      NaN      2006.484616     NaN
# std                             NaN      NaN         5.877050     NaN
# min                             NaN      NaN      1980.000000     NaN
# 25%                             NaN      NaN      2003.000000     NaN
# 50%                             NaN      NaN      2007.000000     NaN
# 75%                             NaN      NaN      2010.000000     NaN
# max                             NaN      NaN      2016.000000     NaN
#
#             NA_sales      EU_sales      JP_sales   Other_sales  Critic_Score  \
# ...

# %% [raw]
# # first step would be clean the data which means remove null and change from float to a string. There are 16715 records that some of the are missing information.

# %%
df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre  NA_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %% [raw]
# # An example of our data and how it is divided

# %%
df.sort_values(by='Year_of_Release')
# Out:
#                                     Name Platform  Year_of_Release  \
# 1764                             Kaboom!     2600           1980.0
# 546                      Missile Command     2600           1980.0
# 1968                            Defender     2600           1980.0
# 6300                              Bridge     2600           1980.0
# 6875                            Checkers     2600           1980.0
# ...                                  ...      ...              ...
# 16373  PDC World Championship Darts 2008      PSP              NaN
# 16405                      Freaky Flyers       GC              NaN
# 16448                          Inversion       PC              NaN
# 16458        Hakuouki: Shinsengumi Kitan      PS3              NaN
# 16522                       Virtua Quest       GC              NaN
#
#               Genre  NA_sales  EU_sales  JP_sales  Other_sales  Critic_Score  \
# 1764           Misc      1.07      0.07       0.0         0.01           NaN
# ...

# %%
df.sort_values(by='Year_of_Release', ascending=False)
# Out:
#                                     Name Platform  Year_of_Release  \
# 16714                Winning Post 8 2016      PSV           2016.0
# 14400                         DiRT Rally       PC           2016.0
# 2024                            NBA 2K17     XOne           2016.0
# 15456            Carmageddon: Max Damage     XOne           2016.0
# 14385                   Tokyo Xanadu eX+      PS4           2016.0
# ...                                  ...      ...              ...
# 16373  PDC World Championship Darts 2008      PSP              NaN
# 16405                      Freaky Flyers       GC              NaN
# 16448                          Inversion       PC              NaN
# 16458        Hakuouki: Shinsengumi Kitan      PS3              NaN
# 16522                       Virtua Quest       GC              NaN
#
#               Genre  NA_sales  EU_sales  JP_sales  Other_sales  Critic_Score  \
# 16714    Simulation      0.00      0.00      0.01         0.00           NaN
# ...

# %% [raw]
# # We are dealing with a range of release year from 1980-2016.

# %%
df.columns= df.columns.str.lower()
print(list(df.columns))
# Out:
# ['name', 'platform', 'year_of_release', 'genre', 'na_sales', 'eu_sales', 'jp_sales', 'other_sales', 'critic_score', 'user_score', 'rating']

# %%
df.describe(include="all")
# Out:
#                                name platform  year_of_release   genre  \
# count                         16713    16715     16446.000000   16713
# unique                        11559       31              NaN      12
# top     Need for Speed: Most Wanted      PS2              NaN  Action
# freq                             12     2161              NaN    3369
# mean                            NaN      NaN      2006.484616     NaN
# std                             NaN      NaN         5.877050     NaN
# min                             NaN      NaN      1980.000000     NaN
# 25%                             NaN      NaN      2003.000000     NaN
# 50%                             NaN      NaN      2007.000000     NaN
# 75%                             NaN      NaN      2010.000000     NaN
# max                             NaN      NaN      2016.000000     NaN
#
#             na_sales      eu_sales      jp_sales   other_sales  critic_score  \
# ...

# %%
df['year'] = df['year_of_release'].astype(str)

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment</b>
#
#
# I believe `int` or date type would be a better choice.
# </div>

# %%
df.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score user_score rating    year
# 0     28.96      3.77         8.45          76.0          8      E  2006.0
# 1      3.58      6.81         0.77           NaN        NaN    NaN  1985.0
# 2     12.76      3.79         3.29          82.0        8.3      E  2008.0
# 3     10.93      3.28         2.95          80.0          8      E  2009.0
# 4      8.89     10.22         1.00           NaN        NaN    NaN  1996.0

# %%
df.isna().sum()
# Out:
# name                  2
# platform              0
# year_of_release     269
# genre                 2
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8578
# user_score         6701
# rating             6766
# year                  0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df[df[['name', 'platform', 'year_of_release']].duplicated(keep=False)]
# Out:
#                 name platform  year_of_release   genre  na_sales  eu_sales  \
# 604    Madden NFL 13      PS3           2012.0  Sports      2.11      0.22
# 659              NaN      GEN           1993.0     NaN      1.78      0.53
# 14244            NaN      GEN           1993.0     NaN      0.00      0.00
# 16230  Madden NFL 13      PS3           2012.0  Sports      0.00      0.01
#
#        jp_sales  other_sales  critic_score user_score rating    year
# 604        0.00         0.23          83.0        5.5      E  2012.0
# 659        0.00         0.08           NaN        NaN    NaN  1993.0
# 14244      0.03         0.00           NaN        NaN    NaN  1993.0
# 16230      0.00         0.00          83.0        5.5      E  2012.0

# %% [markdown]
# We can see there is one case with dulicated names and another case with unknown name and few missing values in it.
# I will drop rows 659,14244, 16230.

# %%
rows_to_drop = [659, 14244, 16230]
df_dropped = df.drop(rows_to_drop)

# %%
df.isna().sum()
# Out:
# name                  2
# platform              0
# year_of_release     269
# genre                 2
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8578
# user_score         6701
# rating             6766
# year                  0
# dtype: int64

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 3</b>
#
#
# Try to apply the same logic as you did before for the whole dataframe. You correctly used `sum` method in order to get the number of duplicates. Here you can also use this method. Would you try? As you see, it is hard to make a conclusion regarding these duplicates, since we can see only first and last five rows. Another approach is to print these rows. You can do it as follows:
#
#
# ```python
#
# df[df[['name', 'platform', 'year_of_release']].duplicated(keep=False)]
#
# ```
#
#
# If there are any duplicates, do not forget to make a conclusion and delete duplicates if needed.
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 4</b>
#
# Exactly! Great job :)
#
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment</b>
#
#
# Very good! However, there can be unobvious duplicates, or duplicates in multiple columns. For example, there may be rows that have the same game's name, genre, year of release, platform and age rating, but they may have different user scores for some reason.
#
#
#
# Try to search them in a columns `'name', 'platform', 'year_of_release'`, for instance.
#
# </div>

# %% [markdown]
# * which code will provide that ?

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2</b>
#
#
# You need to consider these 3 columns in look for the duplicates in there.
#
# </div>

# %%
missing_values_count = df.isnull().sum()
total_values = len(df)
missing_values_percent = (missing_values_count / total_values) * 100


missing_values_table = pd.DataFrame({'Missing Count': missing_values_count,
                                     'Total Count': total_values,
                                     'Missing Percentage': missing_values_percent})
missing_values_table.sort_values(by='Missing Percentage', ascending=False, inplace=True)


print(missing_values_table)
# Out:
#                  Missing Count  Total Count  Missing Percentage
# critic_score              8578        16715           51.319174
# rating                    6766        16715           40.478612
# user_score                6701        16715           40.089740
# year_of_release            269        16715            1.609333
# name                         2        16715            0.011965
# genre                        2        16715            0.011965
# platform                     0        16715            0.000000
# na_sales                     0        16715            0.000000
# eu_sales                     0        16715            0.000000
# jp_sales                     0        16715            0.000000
# other_sales                  0        16715            0.000000
# year                         0        16715            0.000000

# %%
df['name'] = df['name'].fillna('unknown') 
df['genre'] = df['genre'].fillna('unknown')

# %% [markdown]
# I chose to fill the 2 missing values in each column with an "unknown" string.

# %%
df.isna().sum()
# Out:
# name                  0
# platform              0
# year_of_release     269
# genre                 0
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8578
# user_score         6701
# rating             6766
# year                  0
# dtype: int64

# %%
df.year_of_release.unique()
# Out:
# array([2006., 1985., 2008., 2009., 1996., 1989., 1984., 2005., 1999.,
#        2007., 2010., 2013., 2004., 1990., 1988., 2002., 2001., 2011.,
#        1998., 2015., 2012., 2014., 1992., 1997., 1993., 1994., 1982.,
#        2016., 2003., 1986., 2000.,   nan, 1995., 1991., 1981., 1987.,
#        1980., 1983.])

# %%
df = df[df['year_of_release'].notna()]

# %%
df.isna().sum()
# Out:
# name                  0
# platform              0
# year_of_release       0
# genre                 0
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8463
# user_score         6607
# rating             6678
# year                  0
# dtype: int64

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment</b>
#
# Can we replace missing values with just a mean?
#
#
# What is more important here is that we are trying to replace 50% values, which means that the half of the column is going to be artificial. It may play an important role in hypotheses testing.
#
#
# What do you think about it? Shouldn't we just ignore the missing values in critics' and users' ratings?
#
# </div>
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment</b>
#
#
# Sometimes **inplace** doesn't work properly, so I'd recommend you to rewrite dataframe explicitly.
#
# </div>

# %% [markdown]
# After a second thought, this decision changed drasticly the hypotheses testing. could you help me with the code ? how to ignore the missing values

# %% [markdown]
# * just drop the rows with missing values or change it to unknown ?

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2</b>
#
# Deleting 50% of data is also not a good idea. Just ignore them, do not do anything.
#
# </div>

# %%
df.critic_score.unique()
# Out:
# array([76., nan, 82., 80., 89., 58., 87., 91., 61., 97., 95., 77., 88.,
#        83., 94., 93., 85., 86., 98., 96., 90., 84., 73., 74., 78., 92.,
#        71., 72., 68., 62., 49., 67., 81., 66., 56., 79., 70., 59., 64.,
#        75., 60., 63., 69., 50., 25., 42., 44., 55., 48., 57., 29., 47.,
#        65., 54., 20., 53., 37., 38., 33., 52., 30., 32., 43., 45., 51.,
#        40., 46., 39., 34., 41., 36., 31., 27., 35., 26., 19., 28., 23.,
#        24., 21., 17., 13.])

# %%
df.user_score.unique()
# Out:
# array(['8', nan, '8.3', '8.5', '6.6', '8.4', '8.6', '7.7', '6.3', '7.4',
#        '8.2', '9', '7.9', '8.1', '8.7', '7.1', '3.4', '5.3', '4.8', '3.2',
#        '8.9', '6.4', '7.8', '7.5', '2.6', '7.2', '9.2', '7', '7.3', '4.3',
#        '7.6', '5.7', '5', '9.1', '6.5', 'tbd', '8.8', '6.9', '9.4', '6.8',
#        '6.1', '6.7', '5.4', '4', '4.9', '4.5', '9.3', '6.2', '4.2', '6',
#        '3.7', '4.1', '5.8', '5.6', '5.5', '4.4', '4.6', '5.9', '3.9',
#        '3.1', '2.9', '5.2', '3.3', '4.7', '5.1', '3.5', '2.5', '1.9', '3',
#        '2.7', '2.2', '2', '9.5', '2.1', '3.6', '2.8', '1.8', '3.8', '0',
#        '1.6', '9.6', '2.4', '1.7', '1.1', '0.3', '1.5', '0.7', '1.2',
#        '2.3', '0.5', '1.3', '0.2', '0.6', '1.4', '0.9', '1', '9.7'],
#       dtype=object)

# %% [markdown]
# 'tbd' most likely means that it has not been rated by users or the game has been released recantly. I changed it to 'np.nan'

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment</b>
#
# Yes, we can treat it as a missing value.
#
# </div>

# %%
df.loc[df['user_score'].isin(['tbd', 'user_score']), 'user_score'] = np.nan

# %%
df.user_score.unique()
# Out:
# array(['8', nan, '8.3', '8.5', '6.6', '8.4', '8.6', '7.7', '6.3', '7.4',
#        '8.2', '9', '7.9', '8.1', '8.7', '7.1', '3.4', '5.3', '4.8', '3.2',
#        '8.9', '6.4', '7.8', '7.5', '2.6', '7.2', '9.2', '7', '7.3', '4.3',
#        '7.6', '5.7', '5', '9.1', '6.5', '8.8', '6.9', '9.4', '6.8', '6.1',
#        '6.7', '5.4', '4', '4.9', '4.5', '9.3', '6.2', '4.2', '6', '3.7',
#        '4.1', '5.8', '5.6', '5.5', '4.4', '4.6', '5.9', '3.9', '3.1',
#        '2.9', '5.2', '3.3', '4.7', '5.1', '3.5', '2.5', '1.9', '3', '2.7',
#        '2.2', '2', '9.5', '2.1', '3.6', '2.8', '1.8', '3.8', '0', '1.6',
#        '9.6', '2.4', '1.7', '1.1', '0.3', '1.5', '0.7', '1.2', '2.3',
#        '0.5', '1.3', '0.2', '0.6', '1.4', '0.9', '1', '9.7'], dtype=object)

# %%
df.isna().sum()
# Out:
# name                  0
# platform              0
# year_of_release       0
# genre                 0
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8463
# user_score         8983
# rating             6678
# year                  0
# dtype: int64

# %%
df['user_score'] = pd.to_numeric(df['user_score'], errors='coerce')

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment</b>
#
# Don't forget to update the code here as well. Since we do not have a decent replacement for such a huge number of gaps, it is reasonable to ignore them.
#
# </div>

# %% [markdown]
# I did not understand what practiclly it means to update the code ?

# %%
df.isna().sum()
# Out:
# name                  0
# platform              0
# year_of_release       0
# genre                 0
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8463
# user_score         8983
# rating             6678
# year                  0
# dtype: int64

# %%
df.rating.unique()
# Out:
# array(['E', nan, 'M', 'T', 'E10+', 'K-A', 'AO', 'EC', 'RP'], dtype=object)

# %%
df['rating'] = df['rating'].fillna('None')

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment</b>
#
#
# `df['rating'] =='None'` returns either True or False. Is that what you intended to do? I no, you can just fill in the gaps with the string value: `fillna('None')`
# </div>

# %% [markdown]
# I did not understand the differences​.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2</b>
#
# Print both to figure out the difference.
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 3</b>
#
# Great :)
#
# </div>

# %%
df.isna().sum()
# Out:
# name                  0
# platform              0
# year_of_release       0
# genre                 0
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8463
# user_score         8983
# rating                0
# year                  0
# dtype: int64

# %% [markdown]
# I have decided to fill in the missing values in user_score and critic_score with the mean of the column while filled none in rating and years of release.

# %%
df.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score rating    year
# 0     28.96      3.77         8.45          76.0         8.0      E  2006.0
# 1      3.58      6.81         0.77           NaN         NaN   None  1985.0
# 2     12.76      3.79         3.29          82.0         8.3      E  2008.0
# 3     10.93      3.28         2.95          80.0         8.0      E  2009.0
# 4      8.89     10.22         1.00           NaN         NaN   None  1996.0

# %%
df.describe(include="all")
# Out:
#                                name platform  year_of_release   genre  \
# count                         16446    16446     16446.000000   16446
# unique                        11427       31              NaN      13
# top     Need for Speed: Most Wanted      PS2              NaN  Action
# freq                             12     2127              NaN    3307
# mean                            NaN      NaN      2006.484616     NaN
# std                             NaN      NaN         5.877050     NaN
# min                             NaN      NaN      1980.000000     NaN
# 25%                             NaN      NaN      2003.000000     NaN
# 50%                             NaN      NaN      2007.000000     NaN
# 75%                             NaN      NaN      2010.000000     NaN
# max                             NaN      NaN      2016.000000     NaN
#
#             na_sales      eu_sales      jp_sales   other_sales  critic_score  \
# ...

# %%
df['total_sales']=df[['na_sales','eu_sales','jp_sales','other_sales']].sum(axis=1)
df.head(10)
# Out:
#                         name platform  year_of_release         genre  \
# 0                 Wii Sports      Wii           2006.0        Sports
# 1          Super Mario Bros.      NES           1985.0      Platform
# 2             Mario Kart Wii      Wii           2008.0        Racing
# 3          Wii Sports Resort      Wii           2009.0        Sports
# 4   Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# 5                     Tetris       GB           1989.0        Puzzle
# 6      New Super Mario Bros.       DS           2006.0      Platform
# 7                   Wii Play      Wii           2006.0          Misc
# 8  New Super Mario Bros. Wii      Wii           2009.0      Platform
# 9                  Duck Hunt      NES           1984.0       Shooter
#
#    na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score rating  \
# 0     41.36     28.96      3.77         8.45          76.0         8.0      E
# ...

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment</b>
#
# Nice code!
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment</b>
#
#
# - In your opinion, how these missing values could occur? From the task: `Why do you think the values are missing? Give possible reasons.`
#
#
# - Please, add an intermediate conclusion about this introductory part. What have been done, what hypotheses about the data do we have and what we are going to do next.
# </div>

# %% [markdown]
# As I mentioned in the research, most likely that games that have been released recently , have already been bought by users but have not been ranked yet. Another reason might be that normally some of the users buy and play in the games but do not leave a review.
# In a conclusion, about a half of the data rows have missing values in at least one of the column which harden the accuracy and credibility of results.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2</b>
#
# That's better 👍 Intermidiate conclusions are improtant in any project, so don't forget about them.
#
# </div>

# %% [markdown]
# # Step 3

# %%
df_games_sold_by_year =df[['year_of_release','name']].groupby(['year_of_release']).count().sort_values(by='year_of_release').reset_index()
df_games_sold_by_year.head(40)
# Out:
#     year_of_release  name
# 0            1980.0     9
# 1            1981.0    46
# 2            1982.0    36
# 3            1983.0    17
# 4            1984.0    14
# 5            1985.0    14
# 6            1986.0    21
# 7            1987.0    16
# 8            1988.0    15
# 9            1989.0    17
# 10           1990.0    16
# 11           1991.0    41
# 12           1992.0    43
# 13           1993.0    62
# 14           1994.0   121
# 15           1995.0   219
# 16           1996.0   263
# 17           1997.0   289
# 18           1998.0   379
# 19           1999.0   338
# 20           2000.0   350
# 21           2001.0   482
# 22           2002.0   829
# 23           2003.0   775
# 24           2004.0   762
# 25           2005.0   939
# 26           2006.0  1006
# 27           2007.0  1197
# 28           2008.0  1427
# 29           2009.0  1426
# 30           2010.0  1255
# 31           2011.0  1136
# 32           2012.0   653
# 33           2013.0   544
# ...

# %% [raw]
# There is a massive increasing through the years with a decline of around 50% from 2012. One of the reason that it takes few years for a game to be sold in diffrent prices after few years from the released year

# %%
fig,ax=plt.subplots(figsize=(17,10))
ax.vlines(x=df_games_sold_by_year.year_of_release, ymin=0, ymax=df_games_sold_by_year.name,color='blue',alpha=0.7,linewidth=2)
ax.scatter(x=df_games_sold_by_year.year_of_release,y=df_games_sold_by_year.name,s=75,color='black',alpha=0.7)

ax.set_title('Number of Games Released by Year', fontdict={'size':24})
ax.set_ylabel('Number of Games Released', fontdict={'size':18})
ax.set_xlabel('Year', fontdict={'size':24})
ax.set_xticks(df_games_sold_by_year.year_of_release)
ax.set_xticklabels(df_games_sold_by_year.year_of_release,rotation=75)

for row in df_games_sold_by_year.itertuples():
    ax.text(row.year_of_release,row.name+30, s=round(row.name,2))
plt.show()

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment </b>
#
# I like this graph! 😊  Define a zero angle to make the labels horizontal.
#
# </div>
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment </b>
#
#
# Here is where integer or date type may be useful: we do not need zero and floating point in each of the numbers on X-axis.
#
# </div>

# %% [raw]
# # As it is written above, a big leap occur in 1993 and the best years of sales were in between 2007-2010.

# %%
df_platform_sales = df[['platform','total_sales']].groupby(['platform']).sum().sort_values(by='total_sales',ascending=False).reset_index()
df_platform_sales.head(11)
# Out:
#    platform  total_sales
# 0       PS2      1233.56
# 1      X360       961.24
# 2       PS3       931.34
# 3       Wii       891.18
# 4        DS       802.78
# 5        PS       727.58
# 6       PS4       314.14
# 7       GBA       312.88
# 8       PSP       289.53
# 9       3DS       257.81
# 10       PC       255.76

# %%
df_top_platform = df_platform_sales.head(11)

fig, ax = plt.subplots(figsize=(6, 6))


ax.bar(df_top_platform['platform'], df_top_platform['total_sales'])
ax.set_xlabel('Platform')
ax.set_ylabel('Total Sales')
ax.set_title('Top platform Total Sales by Platform')


plt.show()

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment</b>
#
# The second chart is empty. Do we need that?
#
# </div>

# %% [markdown]
# We don't, but I could not remove that for some reason.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2</b>
#
# Why are you using subplots? That's the key.
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 3</b>
#
# Correct.</div>

# %%
df_platform_sales=df.groupby(['platform','year_of_release'])['total_sales'].sum().reset_index()
df_top_platform_years = df_platform_sales.sort_values(by='total_sales',ascending=False)


fig,ax=plt.subplots(figsize=(17,10))
ax.set_title('Alltime Game Sales by Platforms', fontdict={'size':24})
ax.set_ylabel('Sales in Millions', fontdict={'size':18})
sns.boxplot(data=df_top_platform_years, x="platform", y="total_sales")
plt.show()

# %%
df_relative_to_mean = df[['platform','total_sales']].groupby(['platform']).sum().sort_values(by='total_sales').reset_index()
df_relative_to_mean['sales_z']=(df_relative_to_mean['total_sales']-df_relative_to_mean['total_sales'].mean())/df_relative_to_mean['total_sales'].std()
df_relative_to_mean['color'] = ['red' if x<0 else 'green' for x in df_relative_to_mean['sales_z']]

plt.figure(figsize=(12,8))
plt.hlines(y=df_relative_to_mean.platform, xmax=df_relative_to_mean.sales_z, xmin=0, color=df_relative_to_mean.color, alpha=0.5,linewidth=10)

plt.xlabel('Sales', fontdict={'size':20})
plt.ylabel('Platform', fontdict={'size':20})
plt.title("Game Sales Relative to the Mean By platform", fontdict={'size':24})
plt.show()

# %% [raw]
# 9 platform having higher sales comperded to the mean and 22 platform below it.

# %%
df_top_revenue_by_total_sales_column=df_top_platform_years[['year_of_release','total_sales','platform']].groupby(['total_sales','platform']).sum().sort_values(by='total_sales',ascending=False).reset_index()
df_top_revenue_by_total_sales_column.head(15)
# Out:
#     total_sales platform  year_of_release
# 0        211.81      PS2           2004.0
# 1        206.97      Wii           2009.0
# 2        205.38      PS2           2002.0
# 3        184.31      PS2           2003.0
# 4        171.32      Wii           2008.0
# 5        170.03     X360           2010.0
# 6        169.49       PS           1998.0
# 7        166.43      PS2           2001.0
# 8        160.66      PS2           2005.0
# 9        156.78      PS3           2011.0
# 10       152.77      Wii           2007.0
# 11       146.94       DS           2007.0
# 12       145.31       DS           2008.0
# 13       144.53       PS           1999.0
# 14       143.84     X360           2011.0

# %%
df_top_platform_years=df.groupby(['platform','year_of_release'])['total_sales'].sum().reset_index()

fig,ax=plt.subplots(figsize=(17,8))
ax.set_title('Game Sales by Platforms by Year', fontdict={'size':20})
ax.set_ylabel('Sales', fontdict={'size':18})
ax.set_xticks(df_games_sold_by_year.year_of_release)
ax.set_xticklabels(df_games_sold_by_year.year_of_release,rotation=75)
sns.lineplot(data=df_top_platform_years, x="year_of_release", y="total_sales", hue="platform")
plt.show()

# %% [raw]
# It seems that the best seller platforms like PS2,PS3,Wii have a peak of 8-10 years and then a fading

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment </b>
#
# Yes, PS2 is an old platform that had enough time to make a huge sales volume.
#
# </div>

# %%
df_chart = df.groupby(['platform','year_of_release'])['total_sales'].sum().reset_index()
grid = sns.FacetGrid(df_chart, col="platform",col_wrap=6)
grid.map(sns.lineplot, "year_of_release", "total_sales")
plt.show()

# %%
df_platforms_active_in_2016 = df.groupby(['platform', 'year_of_release'])['name'].count().reset_index()
df_platform_years_active = df_platforms_active_in_2016.groupby('platform')['year_of_release'].count().reset_index()
average_life = df_platform_years_active['year_of_release'].mean()
print('The average life of all active and non-active platforms is', average_life)
# Out:
# The average life of all active and non-active platforms is 7.67741935483871

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment</b>
#
# Seems to be true.
#
# </div>
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment</b>
#
#
# I'd use only top 5-10 platforms in order to ignore old PC and unlucky platforms that had a 2 years lifespan.
# </div>

# %%
df_sales_not_in_2016 = df.query('year_of_release != 2016 & total_sales > 0')
print("Latest year of release in new dataset", df_sales_not_in_2016.year_of_release.max())
print('Smallest total sales in new dataset',df_sales_not_in_2016.total_sales.min())
print('Number of records in new dataset',df_sales_not_in_2016.platform.count())
# Out:
# Latest year of release in new dataset 2015.0
# Smallest total sales in new dataset 0.01
# Number of records in new dataset 15942

# %%
df_platforms_not_active_in_2016 = df_sales_not_in_2016.groupby(['platform','year_of_release'])['name'].count().reset_index()
df_platform_years = df_platforms_not_active_in_2016[['platform','year_of_release']]
df_platform_years_not_active = df_platform_years.groupby(['platform'])['year_of_release'].count().reset_index()
print('The average life of our currently active platforms is',df_platform_years_not_active.year_of_release.mean(),'years')
# Out:
# The average life of our currently active platforms is 7.387096774193548 years

# %%
relevant_platforms = ['Wii', 'X360', 'PS3', 'PS4', '3DS', 'PC', 'XOne', 'WiiU', 'PSV']
# There must be a way to use this to do this quicker

df_cleaned = df[df['platform'].isin(relevant_platforms)]

df_cleaned = df_cleaned[df_cleaned['year_of_release'] >= 2012]
print(len(df_cleaned), len(df))
# Out:
# 2682 16446

# %% [markdown]
# I focused in the relevant platforms that I find necessary in order to have insights from the data.
# Moreover, the relevant years are from 2008 to 2016 (the platforms that still active in the market).

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment</b>
#
# - Imagine we have 50 platforms. Is it a good idea to eliminate them one by one? Try to use pandas approach :)
#
#
#
# - Solving this task, I also took about 10 years first. But then I realized that the market is dynamic, everything is changing. Some popular genre may not remain popular 10 years later. And vice versa. So during this time several plarform generations will change :) The industry is evolving, the games are getting better, the graphics is better and the users are more demanding. In such tasks, we need fresh information, fresh estimation. If we forecast for 2017, then who cares what happened 10 years ago?  Potentially profitable platforms can be easily selected with charts and pivot tables. But user portraits may change. If you look at the sales chart, you will see in which year the market stabilized after huge volume sales. We can also take the half of a lifetime period.
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2</b>
#
#
# - A lot of things may change in 10 years. No only do we have old platforms, but we also may have different genre distribution. Just think about racing games that were very popular and suddenly lost their popularity. The same thing happened with western movies that ceased to be so popular in about 10 years.
#
#
# - Don't forget to update the code making it more flexible. In other words, replace all `df_cleaned.platform !=` conditions with one slice only. For this purpose, you can use a list of relevant platforms.  </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 3</b>
#
#
# - A `~` sign means `not`. Therefore, the code fragment `df[~df['platform'].isin(relevant_platforms)]` gives us all rows from the `df` dataframe where platform name is not in the list `relevant_platforms`. Just remove `~`, and everything will be ok :)
#
#
# - Now let's consider relevant time period. You decided to take everything from 2010, but let's take a look at the first chart:
#
#
# ![image.png](attachment:image.png)
#
#
#
# A red line separates a period where there are no huge sales. 2010 and 2011 can skew our distributions because of such tremendous sales volumes that drastically differ from other years' volumes. Moreover, new platforms, such as PS4 and XOne, appeared in 2013, so 2010 may be irrelevant for our analysis. Let's just take everything from at least 2012. Such choice will eliminate the influence of 2010 and 2011 with their high volumes. </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 4</b>
#
# Great. It is a good choice because we will able to analyze recent trends only.
# </div>

# %%
df_top_platform_years=df_cleaned.groupby(['platform','year_of_release'])['total_sales'].sum().reset_index()
print(df_top_platform_years.year_of_release.min())
print(df_top_platform_years.year_of_release.max())
# Out:
# 2012.0
# 2016.0

# %%
fig,ax=plt.subplots(figsize=(17,10))
ax.set_title('Game Sales by Top Platforms by Year', fontdict={'size':24})
ax.set_ylabel('Sales(M)', fontdict={'size':18})
ax.set_xlabel('Year', fontdict={'size':18})
ax.set_xticks(df_top_platform_years.year_of_release)
ax.set_xticklabels(df_top_platform_years.year_of_release)

sns.lineplot(data=df_top_platform_years, x="year_of_release", y="total_sales", hue="platform",ci=None)
plt.show()

# %%
grid = sns.FacetGrid(df_top_platform_years, col="platform",col_wrap=4)
grid.map(sns.lineplot, "year_of_release", "total_sales")
print("Game Sales by Top Platforms by Year")
# Out:
# Game Sales by Top Platforms by Year

# %% [markdown]
# 1. We can notice there is a decline in whole market.
# 2. PS3 and X360 declied sharply.
# 3. It seems that in this market. platform having a quick hit for few years and then lose popularity rapidly.
# 4. Xone platform might be a good idea to put effort and resources for increase the sales.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment</b>
#
#
# > PSP and PC are more stable than others
#
#
# PSP sales are going down to the zero and does not have any sales in 2016. Please, resconsider the conclusion. Try to use pivot table because it may be easier to compare numbers than to compare charts.
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2</b>
#
#
# This one is still relevant.
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 4 </b>
#
# Agreed.
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 4</b>
#
#
# However, according to the graph above, there are more than one promising platforms. Consider the pivot table below. Is there anything we can take into account?</div>

# %%
# Reviwer's code 4

df_cleaned.pivot_table(index='year_of_release', columns='platform', values='total_sales', aggfunc='sum')
# Out:
# platform           3DS     PC     PS3     PS4    PSV    Wii   WiiU   X360  \
# year_of_release
# 2012.0           51.36  23.22  107.36     NaN  16.19  21.71  17.56  99.74
# 2013.0           56.57  12.38  113.25   25.99  10.59   8.59  21.65  88.58
# 2014.0           43.76  13.28   47.76  100.00  11.90   3.75  22.03  34.74
# 2015.0           27.78   8.52   16.82  118.90   6.25   1.14  16.35  11.96
# 2016.0           15.14   5.25    3.60   69.25   4.25   0.18   4.60   1.52
#
# platform          XOne
# year_of_release
# 2012.0             NaN
# 2013.0           18.96
# 2014.0           54.07
# 2015.0           60.14
# 2016.0           26.15

# %% [markdown]
# According to the pivot table above, we can clearly see a decline of sales in all the platforms. The 2 platforms that had better preformence in 2016 than 2013 are PS4 and XOne and worth to invest in there marketing.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 5</b>
#
# Correct! 3DS also has high sales volume.
#
# </div>

# %%
df_relative_to_mean = df_cleaned[['platform','total_sales']].groupby(['platform']).sum().sort_values(by='total_sales').reset_index()
grouped=df_cleaned.groupby(['platform','year_of_release'])['total_sales'].sum().reset_index()
sns.boxplot(x='platform',y='total_sales',data=grouped,showfliers=False)
plt.title("How The Platform Relates to Sales grouped by year of release")
plt.show()

# %%
df_relative_to_mean = df_cleaned[['platform','total_sales']].groupby(['platform']).sum().sort_values(by='total_sales').reset_index()
grouped=df_cleaned.groupby('platform')['total_sales'].sum().reset_index()
sns.boxplot(x='platform',y='total_sales',data=grouped,showfliers=False)
plt.title("How The Platform Relates to Sales")
plt.show()

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2</b>
#
#
# The code still does not work. Check it out so I can continue the review. </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 3</b>
#
#
# Don't forget to fix that. </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 4</b>
#
# Very good.
#
# </div>
#
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 4</b>
#
#
# There's an issue though.
#
#
# - Actually, we don't need to group by year here, the idea is to show the distribution (boxplot show the distribution) of the sales for each platform, taking into account every single game. So, we just need to group by platform, that's all.
#
#
#
#
# - There will be some outliers there, don't drop them. What do you think outliers can tell us? Just write any suggestions you have. If it is difficult to compare the boxes after yuo add outliers on the chart, try to use **ylim**, it will scale the graph</div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 5</b>
#
#
# Still relevant. We do not need to group by years in order to display a boxplot. </div>

# %%
df_relative_to_mean = df_cleaned[['platform', 'total_sales']].groupby(['platform']).sum().sort_values(by='total_sales').reset_index()

sns.boxplot(x='platform', y='total_sales', data=df_cleaned, showfliers=False)

plt.title("How The Platform Relates to Sales")
plt.xlabel("Platform")
plt.ylabel("Total Sales")
plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 6</b>
#
# Keep it simple:
# </div>

# %%
# Reviewer's code 6

df_cleaned.boxplot('total_sales', by='platform', figsize=(12,7))
plt.ylim(0,3)
# Out:
# (0.0, 3.0)

# %% [markdown]
# Could be the ouliers are NaN details of 2012 in some of the platforms.

# %% [markdown]
# PS4, X360, PS3 are the most profatble according the significant differences.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 6</b>
#
#
#
# Boxplot shows us a distribution, like a histogram. 2 pictures below represent it:
#
#
# ![image info](https://r-charts.com/en/distribution/histogram-boxplot_files/figure-html/histogram-boxplot.png)
#
#
# ![image.png](https://i.ytimg.com/vi/FPREzlHdWRY/maxresdefault.jpg)
#
#
#
# But the boxplot is better, since we don't have to think about `bins` parameter for a histogram. Boxplot also shows us some statistics, while histogram doesn't.
#
#
# What does our boxplot tell us about? Since we are plotting sum world sales per game, outliers are just some very popular games. I would even say bestsellers. And this is a very illustrative thing. Look at the 3DS. Small box and lots of outliers. This suggests that a large part of the sales volume comes from these outliers. At the same time, the XOne has a different situation: a large box, a long whisker and few outliers. This indicates that a wide variety of games are bought on XOne, and, moreover, in considerable quantities.
#
# That's why it may be useful to plot 2 graphs: with and without outliers. Just to evaluate the distribution.
#
# That's how you can interpret boxplots. </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment</b>
#
#
# - Please, don't forget to run the whole project before you send it for a review.
#
#
# - Why did you decide to ignore the outliers? Let's display them because they can convey important information. Don't forget to use `ylim` parameter to make the chart more comprehensible.
#
#
# - Don't forget about the conclusion. What can we say about the distribution? What do outliers tell us?
# </div>
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment</b>
#
#
#
#
# In the code below, `where` assigns Nan-s to every row that does not have PS4 as a platform. It is not a good approach, since you do not reduce the length of the dataframe. It is much better to make more explicit slice: `df_cleaned[df_cleaned['platform']=="PS4"]`
#
#
# </div>

# %%
ps4 = df_cleaned.where(df_cleaned['platform']=="PS4")
correlation_coefficient_1 = ps4['critic_score'].corr(ps4['total_sales'])
sns.scatterplot(data=ps4, x="critic_score", y="total_sales")
plt.title('How Critic Score Relates to Sales for ps4 (Correlation: {:.2f})'.format(correlation_coefficient_1))
plt.ylabel('Sales')
plt.xlabel('Critic Score')
plt.show()

# %% [markdown]
# A non-significant correlation. We can see the even in high critic scores the sales were nearly 0.

# %%
ps4 = df_cleaned.where(df_cleaned['platform']=="PS4")
correlation_coefficient_2 = ps4['user_score'].corr(ps4['total_sales'])
sns.scatterplot(data=ps4, x="user_score", y="total_sales")
plt.title('How User Score Relates to Sales for ps4 (Correlation: {:.2f})'.format(correlation_coefficient_2))
plt.ylabel('Sales')
plt.xlabel('User Score')
plt.show()

# %% [markdown]
# We can see a tight correlation between user score and critic score in PS4 platform.

# %%
ps3 = df_cleaned.where(df_cleaned['platform']=="PS3")
correlation_coefficient_3 = ps3['critic_score'].corr(ps3['total_sales'])
sns.scatterplot(data=ps3, x="critic_score", y="total_sales")
plt.title('How Critic Score Relates to Sales for ps3 (Correlation: {:.2f})'.format(correlation_coefficient_3))
plt.ylabel('Sales')
plt.xlabel('Critic Score')
plt.show()

# %%
ps3 = df_cleaned.where(df_cleaned['platform']=="PS3")
correlation_coefficient_4 = ps3['user_score'].corr(ps3['total_sales'])
sns.scatterplot(data=ps3, x="user_score", y="total_sales")
plt.title('How User Score Relates to Sales for ps3 (Correlation: {:.2f})'.format(correlation_coefficient_4))
plt.ylabel('Sales')
plt.xlabel('User Score')
plt.show()

# %% [markdown]
# However, in PS3 the using score is more sporadic realtivly to sales and there is an effect that seems in 4-6 score the sales are higher then in higher scores.

# %%
X360 = df_cleaned.where(df_cleaned['platform']=="X360")
correlation_coefficient_5 = X360['critic_score'].corr(X360['total_sales'])
sns.scatterplot(data=X360, x="critic_score", y="total_sales")
plt.title('How Critic Score Relates to Sales for X360 (Correlation: {:.2f})'.format(correlation_coefficient_5))
plt.ylabel('Sales')
plt.xlabel('Critic Score')
plt.show()

# %%
X360 = df_cleaned[df_cleaned['platform'] == "X360"]
correlation_coefficient_6 = X360['user_score'].corr(X360['total_sales'])
sns.scatterplot(data=X360, x="user_score", y="total_sales")
plt.title('How User Score Relates to Sales for X360 (Correlation: {:.2f})'.format(correlation_coefficient_6))
plt.ylabel('Sales')
plt.xlabel('User Score')
plt.show()

# %% [markdown]
# In the case of X360 we can witness to tight correlation between User Score and Critic Score.
# In a conclusion, there is a clear correlation between User Score and Critic score in terms of total sales among PS3 and X360 and a partial correlation in PS4.

# %% [markdown]
# We notice there is a partly Correlation between critic score and sales in X360,PS3,PS4 but no correlation between user score and sales among the 3 platforms above.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 6</b>
#
#
# You have correct charts now, great job!
#
#
# Don't forget about the correlation coefficients.
#
#
# ![image.png](attachment:image.png)</div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 7</b>
#
# I see correlation now, thank you.
#
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment</b>
#
#
# What about users' scores and correlation coefficients?
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 4</b>
#
#
# This one is still relevant. There are no charts that represent the connetion between sales in users' scores. There are no correlation coeff-s as well. Moreover, according to the task, we have to analyze one platform and compare it with other platforms. Since they use plural and since you already have to platforms, you need to add a least one more platform in your analysis.
#
#
# To sum up, for the two platforms above (PS4 and PS3) add two scatter plots (users' scores - total sales) and correlation coefficients for the pairs `sales - users' scores` and `sales - critics' scores`. Then choose one more platform and repeat the analysis.
#
#
# The idea here is very simple: a conclusion made based on 3 platforms is more compelling compared to the conclusion based on two platforms.
# </div>

# %% [markdown]
# I tried few codes about comment 10, I would like to have some help if you can

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 5</b>
#
#
# What did you try? I do not see anything new here.</div>

# %%
ps3 = df_cleaned.where(df_cleaned['platform']=="PS3")
sns.scatterplot(data=ps3, x="critic_score", y="total_sales")
plt.title('How Critic Score Relates to Sales for PS3')
plt.ylabel('Sales')
plt.xlabel('Critic Score')
plt.show()

# %% [markdown]
# There is a similarty between the platforms in terms of a non-significant correlation between the variables  of sales and critic score.

# %%
df_profit_by_genre = df_cleaned[['genre', 'na_sales', 'eu_sales', 'jp_sales']].groupby(['genre']).mean()

fig, ax = plt.subplots(figsize=(17, 10))
ax.vlines(x=df_profit_by_genre.index, ymin=0, ymax=df_profit_by_genre['na_sales'], color='blue', alpha=0.7, linewidth=2)
ax.scatter(x=df_profit_by_genre.index, y=df_profit_by_genre['na_sales'], s=75, color='orange', alpha=0.7)
ax.set_title('Number of Game Titles Released by Genre', fontdict={'size': 24})
ax.set_ylabel('Number of Game Titles Released', fontdict={'size': 24})
ax.set_xticks(df_profit_by_genre.index)
ax.set_xticklabels(df_profit_by_genre.index, rotation=75)

plt.show()

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 5</b>
#
#
# Every time you have a code error, run it piece by piece. In the code above, you are trying to take a mean of names. </div>

# %% [markdown]
# When we use the mean of the sales per genre, we can see that Shooter and sports are the most profitable genres per 1 unit of game.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 7</b>
#
# So, Action is not so good. It gained its volums due to the abundance of games, but shooter, with a smaller number of games, have at least commensurate sales volumes, which means people like this genre. In contrast, action may have games that are rarely bought. That is why we should always compare sum and mean/median values.
#
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment</b>
#
#
# Is it possible that action has made such volumes only due to the number of games? Maybe other genres have more sales per game unit. Please, do the same, but with median or average sales.
#
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 4</b>
#
#
# This comment is still relevant as well. We should also consider average or median sales because Action genre may have a lot of games. For example, Action has 1000 games that are sold \\$1 apiece. Shooter has 10 games that are sold \\$150 apiece. If each game in this set is sold only once, then shooter is more profitable because it generated \\$1500 income while Action generated only \\$1000. I hope this example illustrates the idea I want to convey :)
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 6</b>
#
#
# Please plot mean or median sales values of each genre and draw a conclusion.
#
# </div>

# %% [markdown]
# # Step 4

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment</b>
#
#
# The distributions may change after the time period slice is rectified.
# </div>

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2682 entries, 16 to 16714
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             2682 non-null   object
#  1   platform         2682 non-null   object
#  2   year_of_release  2682 non-null   float64
#  3   genre            2682 non-null   object
#  4   na_sales         2682 non-null   float64
#  5   eu_sales         2682 non-null   float64
#  6   jp_sales         2682 non-null   float64
#  7   other_sales      2682 non-null   float64
#  8   critic_score     1310 non-null   float64
#  9   user_score       1524 non-null   float64
#  10  rating           2682 non-null   object
#  11  year             2682 non-null   object
#  12  total_sales      2682 non-null   float64
# dtypes: float64(8), object(5)
# memory usage: 357.9+ KB

# %%
region_distribution = df_cleaned[['platform', 'na_sales', 'eu_sales', 'jp_sales', 'other_sales']].groupby('platform').sum().sort_values(by='na_sales', ascending=False).reset_index()
region_distribution.plot(x='platform', kind='bar', stacked=True)
plt.title('Sales by Platform')
plt.xlabel('Platform')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# Quite obviously the sales in general in North America are the highest compered the other regions.
# PS3 and PS4 have better sales im europe compered North America.
# 3DS and PSP are more popular and japen than other platforms.

# %% [markdown]
# The top 5 platforms are X360,PS4,PS3,XOne,3DS.
# Relativly, 3DS has more sales in japen than other platforms while PS3 and PS4 are best sellers in region that are not japan, Europe and North America.
# XOne is mostly being sold in North America while PC is mainly sold in Europe.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 4</b>
#
#
# Seem like people in Japan prefer portable platforms and japanese market. We definitely should not recommend them XBox :)
#
# </div>
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 4</b>
#
#
# Three charts will look better than one stacked chart.
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 4</b>
#
# We are asked to define top-5 platforms, which means we have to either plot 5 of them, or outline this top in the conclusion. </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 5</b>
#
#
# That's better! 😊
#
# </div>

# %%
region_distribution = df_cleaned[['genre', 'na_sales', 'eu_sales', 'jp_sales', 'other_sales']].groupby('genre').sum().sort_values(by='na_sales', ascending=False).reset_index()
region_distribution.plot(x='genre', kind='bar', stacked=True)
plt.title('Sales by Genre')
plt.xlabel('genre')
plt.ylabel('Sales')
plt.show()

# %%
pivot_na_sales = df_cleaned.pivot_table(index='year_of_release', columns='genre', values='na_sales', aggfunc='sum')
top_na_genres = pivot_na_sales.sum().nlargest(5)

pivot_eu_sales = df_cleaned.pivot_table(index='year_of_release', columns='genre', values='eu_sales', aggfunc='sum')
top_eu_genres = pivot_eu_sales.sum().nlargest(5)

pivot_jp_sales = df_cleaned.pivot_table(index='year_of_release', columns='genre', values='jp_sales', aggfunc='sum')
top_jp_genres = pivot_jp_sales.sum().nlargest(5)

pivot_other_sales = df_cleaned.pivot_table(index='year_of_release', columns='genre', values='other_sales', aggfunc='sum')
top_other_genres = pivot_other_sales.sum().nlargest(5)

print(top_na_genres)
print(top_eu_genres)
print(top_jp_genres)
print(top_other_genres)
# Out:
# genre
# Action          177.00
# Shooter         144.77
# Sports           81.38
# Role-Playing     60.65
# Misc             38.13
# dtype: float64
# genre
# Action          158.43
# Shooter         113.47
# Sports           68.84
# Role-Playing     46.76
# Racing           27.29
# dtype: float64
# genre
# Role-Playing    59.12
# Action          49.18
# Misc            12.45
# Simulation      10.35
# Shooter          9.23
# dtype: float64
# genre
# Action          50.93
# Shooter         37.26
# Sports          22.35
# Role-Playing    14.38
# Misc             7.62
# dtype: float64

# %% [markdown]
# In regions NA, EU and others Sales by Genre Relatively are the same  and no financial insighs are revealed.
# In conradiction to above, sinulation and Role-Playing are more popular in japen than other regions.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 4</b>
#
#
# -
# > Sales by Genre Relatively are the same in all the regions and no financial insighs are revealed.
#
#
# Are they? For a better comprehension you may want to display three separate charts instead of one stacked chart.
#
#
# - Here is the same the same issue. Please, specify top-5 genre in each region.
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 6</b>
#
#
# For some reason, Japanese also don't like shooters as much as people in NA and EU do.
#
# </div>

# %% [markdown]
# I am trying to create a pivot table to show the numbers Accurately.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 5</b>
#
# > I am trying to create a pivot table to show the numbers Accurately.
#
# Please, don't forget to add this table :)
# </div>

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment</b>
#
#
# Don't forget to reconsider the conclusion.</div>

# %%
ESRB_sales_by_region = df_cleaned[['rating', 'na_sales', 'eu_sales', 'jp_sales', 'other_sales']].groupby(['rating']).sum().sort_values(by='na_sales', ascending=False).reset_index()
ESRB_sales_by_region.set_index('rating', inplace=True)
ESRB_sales_by_region.plot(kind='bar', stacked=True)

plt.title('ESRB Sales by Region')
plt.ylabel('Total Sales')
plt.xlabel('Rating')
plt.show()

# %%
ESRB_sales_by_region
# Out:
#         na_sales  eu_sales  jp_sales  other_sales
# rating
# M         231.57    193.96     21.20        63.38
# E         113.44    111.79     27.62        31.13
# None      100.13     89.32     95.62        26.70
# E10+       75.09     54.84      8.19        16.13
# T          66.02     52.96     25.76        17.94

# %% [markdown]
# The graph above shows that M rating has the highest total sales and even per region except Japen.
# Another insight is that "none" rating has the second highest sales so there is no correlacion between giving rating and buying the game (specially in Japen).
# E10+ has the lowest sales in total but T rating has the lowest sales in 2 out of 4 regions.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment </b>
#
# There's no conclusion regarding ESRB difference.
#
#
# In addition, make sure you add the overall conclusion for step 4. </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 4 </b>
#
# - Unfortunately, it is not clear what 0, 1, 2, 3 and 4 mean.
#
#
# - Does Y-axis represent Rating? Does X-axis represent platforms? What does this chart represent: rating or sales? I believe labels and title should be modified.
#
#
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 5 </b>
#
# You need to specify  labels correctly. Does Y axis represent rating? What do digits on X axis mean?
#
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 6 </b>
#
# > Y axis represents rating and X axis represents top 5 platforms
#
#
# Does it? Is 500 a rating value? Is 300 a rating value? Why does X axis represent platforms and which platforms? As we know, top-5 differs among regions. Even if X axis represents platforms, why do have `rating` label there? Reconsider this solution please.
#
#
# We have to show the distribution of total sales values depending on different rating valus in three regions. </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 7 </b>
#
# These are not platforms.  Let's print the table you are trying to plot: </div>

# %%
# Reviewer's code 7

ESRB_sales_by_region

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 7 </b>
#
# Are there any platforms here? You displayed indices.
#
#
# So, in order to make it clear, make rating column index column and plot the chart. Then draw a conclusion.</div>

# %% [markdown]
# # Step 5

# %%
df_cleaned['user_ratings_float'] = pd.to_numeric(df_cleaned['user_score'], errors='coerce')
df_xone = df_cleaned.where(df_cleaned.platform == "XOne")
df_pc = df_cleaned.where(df_cleaned.platform == "PC")
df_platform_filtered = df_cleaned.query('platform == "XOne" | platform =="PC"')
df_platform_filtered.platform.unique()
# Out:
# array(['XOne', 'PC'], dtype=object)

# %%
df_platform_filtered.describe()
# Out:
#        year_of_release    na_sales    eu_sales    jp_sales  other_sales  \
# count       497.000000  497.000000  497.000000  497.000000   497.000000
# mean       2014.468813    0.225835    0.179779    0.000684     0.040322
# std           1.336346    0.491933    0.315749    0.003694     0.077975
# min        2012.000000    0.000000    0.000000    0.000000     0.000000
# 25%        2014.000000    0.000000    0.020000    0.000000     0.000000
# 50%        2015.000000    0.040000    0.060000    0.000000     0.010000
# 75%        2016.000000    0.210000    0.180000    0.000000     0.040000
# max        2016.000000    4.590000    2.190000    0.040000     0.680000
#
#        critic_score  user_score  total_sales  user_ratings_float
# count    367.000000  388.000000   497.000000          388.000000
# mean      74.681199    6.472165     0.446620            6.472165
# std       11.691352    1.536750     0.833222            1.536750
# ...

# %%
sns.boxplot(x="platform", y="user_ratings_float", data=df_platform_filtered)
plt.ylabel("User Rating", size=14)
plt.xlabel("Platform", size=14)
plt.title("User Ratings by Platform", size=16)
plt.show()

# %% [markdown]
# Pc has slightly better User rating.

# %% [raw]
# Null hypothesis : The average ratings given by users of PC and XOne platforms are similar.
# alternative hypothesis: The average ratings given by of PC and XOne platforms are different.

# %%
alpha = 0.05  
results = st.ttest_ind(df_xone['user_ratings_float'], df_pc['user_ratings_float'])

if results.pvalue < alpha:
    print("We reject the null hypothesis")
else:
    print("We can't reject the null hypothesis")
# Out:
# We can't reject the null hypothesis

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment </b>
#
# We reject the Null hypothesis when pvalue is less than alpha. </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 4 </b>
#
#
# Correct.
#
# </div>

# %%
alpha = 0.01 
results = st.ttest_ind(df_xone['user_ratings_float'], df_pc['user_ratings_float'])

if results.pvalue < alpha:
    print("We reject the null hypothesis")
else:
    print("We can't reject the null hypothesis")
# Out:
# We can't reject the null hypothesis

# %%
df_action = df_cleaned.where(df_cleaned.platform == "Action")
df_Shooter = df_cleaned.where(df_cleaned.platform == "Shooter")
df_genre_filtered = df_cleaned.query('genre == "Action" | genre =="Shooter"')
df_genre_filtered.genre.unique()
# Out:
# array(['Action', 'Shooter'], dtype=object)

# %%
sns.boxplot(x="genre", y="user_ratings_float", data=df_genre_filtered)
plt.ylabel("User Rating", size=14)
plt.xlabel("Genre", size=14)
plt.title("User Ratings by Genre", size=16)
plt.show()

# %% [markdown]
# The average rating of Action Genre is higher compered the Shooter genre among the most popular genres.

# %% [markdown]
# Null hypothesis : The average ratings given by users to genres shooter and action are similar.
# alternative hypothesis: The average ratings given by users to shooter and action are different.

# %%
alpha = 0.05
results = st.ttest_ind(df_Shooter['user_ratings_float'], df_action['user_ratings_float'])

if results.pvalue < alpha:
    print("We reject the null hypothesis")
else:
    print("We can't reject the null hypothesis")
# Out:
# We can't reject the null hypothesis

# %%
alpha = 0.01
results = st.ttest_ind(df_Shooter['user_ratings_float'], df_action['user_ratings_float'])

if results.pvalue < alpha:
    print("We reject the null hypothesis")
else:
    print("We can't reject the null hypothesis")
# Out:
# We can't reject the null hypothesis

# %% [markdown]
# I chose to show two cases of alpha (0.01 is more conservative). We could not rejected the null hypothesis in both of the cases and prove that there is a diffrence in two of the examination.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 4 </b>
#
#
# Correct.
#
# </div>

# %% [markdown]
# # Step 6 - General Conclusion

# %% [markdown]
# The industry has been on a general decline since peaking around 2008. There are no currently active games released prior to 2007.The average lifecycle of a platform is 7-8 years, but most of the bigger players in the industry have longer lifecycles and crossover many years during platform upgrades (especially Sony platforms).
# Reviews and sales are positively correlated although not in a distinct way, Many users rank positively the games without evidential sales influation.
# Action, sports and shooter Genres are significantly more popular than all the rest.
# North America and the EU comprise most of the sales in all the genres and almost all the platforms.
# The most clear and distinct conclusion from the data is a consistant decline in sales and popularity in videos games, could be that one of the reasons is a shift youngers to the social media platforms.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment</b>
#
#
# The conclusion is written well.
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment</b>
#
# It will be great if you add a list of promising platforms and more information about regions: 2-3 platforms, 2-3 genres and age ratings. Also remember to update the final conclusion after the corrections.
# </div>

# %% [markdown]
# I am stucked at review 23. I can not understand why only 3 platforms remainded . Moreover , can you fix the cell above to what it was ?

# %% [markdown]
# I added few notes above that are about the recomended codes for solving the issues I am dealing with.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 4 </b>
#
#
# Very good job, I am happy to see the progress 😊 That's a hard project, so do not worry about the issues. Moreover, it is good that we have them because you can leran a lot. Please, do not hesitate if you have any questions.
# </div>
